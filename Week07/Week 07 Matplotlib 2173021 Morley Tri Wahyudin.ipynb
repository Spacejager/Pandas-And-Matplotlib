# %% [markdown]
# Week 07

# %% [markdown]
# 3D Plotting

# %% [markdown]
# Dalam sesi ini kita akan belajar cara membuat 3d Plotting dengan matplotlib

# %% [markdown]
# Import Modules

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %% [markdown]
# 3D Axes

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 3D Line Plot

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection= '3d')

ax.plot(x, y, z, color='red')

ax.set(title= 'Contoh 3D Line Plot',
       xlabel= 'Sumbu x',
       ylabel= 'Sumbu y',
       zlabel= 'Sumbu z',)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 3D Scatter Plot

# %%
z = np.linspace(0,1,100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection= '3d')

ax.scatter(x, y, z, color='green')

ax.set(title= 'Contoh 3D Line Plot',
       xlabel= 'Sumbu x',
       ylabel= 'Sumbu y',
       zlabel= 'Sumbu z',)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Countour Plot

# %% [markdown]
# Dalam Sesi ini kita belajar cara membuat contour plot dengan Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %%
n = np.linspace(-3.0, 3.0, 100)
x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# Contour Plot

# %%
plt.contour(x, y, z)
plt.colorbar()

plt.title('Contour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# Filled Contour Plot

# %%
plt.contourf(x, y, z)
plt.colorbar()

plt.title(' Filled Contour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# 3D Area Plotting

# %% [markdown]
# Dalam Sesi Ini kita belajar membuat 3d Area Plotting dengan Matplotlib

# %% [markdown]
# Import Modules

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.4.3
# 1.20.3

# %% [markdown]
# Sample DataSet

# %%
n = np.linspace(-3.0, 3.0, 100)
x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %% [markdown]
# 3D WireFrame

# %%
fig = plt.figure()
ax = plt.axes(projection= '3d')

ax.plot_wireframe(x, y, z, color='orange')


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Wireframe')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 3D Surface Plot

# %%
fig = plt.figure()
ax = plt.axes(projection= '3d')

ax.plot_surface(x, y, z, color='orange')


ax.set_xlabel ('X')
ax.set_ylabel ('Y')
ax.set_zlabel ('Z')
ax.set_title ('3D Surface Plot')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
